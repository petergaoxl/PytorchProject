# %% [markdown]
# <a href="https://colab.research.google.com/github/petergaoxl/PytorchProject/blob/main/Intro_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 00. Pytorch foundamentals

# %%
import torch
